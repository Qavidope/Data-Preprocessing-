# %% [markdown]
# #Ordinal variables are categorical variable in which categories can be meaningfully ordered
# >like ex: rating of product grade a,b,c,d
#
#
# #nominal variables is same like ordinal variable but there is nothing that indicates an intrinsic order of labels and in
# principle
# >like ex: all labels are equla no order like example color:red , green ,pink

# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option("display.max_columns",None)  #it show all columns 
pd.set_option("display.max_rows",None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.value_counts()
# Out:
# Series([], dtype: int64)

# %%
df2=df[["KitchenQual","BldgType"]]

# %%
df2.head(4)
# Out:
#   KitchenQual BldgType
# 0          Gd     1Fam
# 1          TA     1Fam
# 2          Gd     1Fam
# 3          Gd     1Fam

# %%
le=LabelEncoder()

# %%
le.fit_transform(df2['BldgType'])
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df2["BldgType_L_enc"]=le.fit_transform(df2['BldgType'])  #label encoding transform variables into number form 
df2.head(6)
# Out:
# C:\Users\qavia\AppData\Local\Temp\ipykernel_22636\3252235510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["BldgType_L_enc"]=le.fit_transform(df2['BldgType'])  #label encoding transform variables into number form
#   KitchenQual BldgType  BldgType_L_enc
# 0          Gd     1Fam               0
# 1          TA     1Fam               0
# 2          Gd     1Fam               0
# 3          Gd     1Fam               0
# 4          Gd     1Fam               0
# 5          TA     1Fam               0

# %%
df['BldgType'].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
df["KitchenQual"].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
# ex -excellent 
# gd good 
# ta typical /average 
# fa fair

# %%
order_Label={"Ex":4,"Gd":3,"TA":2,"Fa":1}

# %%
df2["KitchenQual_org_enc"] = df2['KitchenQual'].map(order_Label)
# Out:
# C:\Users\qavia\AppData\Local\Temp\ipykernel_22636\1514992020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["KitchenQual_org_enc"] = df2['KitchenQual'].map(order_Label)

# %%
df2.head(10)
# Out:
#   KitchenQual BldgType  BldgType_L_enc  KitchenQual_org_enc
# 0          Gd     1Fam               0                    3
# 1          TA     1Fam               0                    2
# 2          Gd     1Fam               0                    3
# 3          Gd     1Fam               0                    3
# 4          Gd     1Fam               0                    3
# 5          TA     1Fam               0                    2
# 6          Gd     1Fam               0                    3
# 7          TA     1Fam               0                    2
# 8          TA     1Fam               0                    2
# 9          TA   2fmCon               1                    2

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# #feature scaling is method to scale numeric features in the same scale or range(1 to 1 , 0to 1)
# #this step involved in data preprocessing and before ml model training
# #it is also called as data normalization
# #we apply feature scaling on independent variables
# we fit feature scaling with train data and transform on train and test data
# #the scale of raw feature is differnet according to its units
# machine learning algo can't understand features units , understand only numbers

# %% [markdown]
# #ml algo required feature scaling
# those algo calculate distance
# knn
# k-means
# support vector machine svm
# pcs principal component analysis
# linear disciminant analysis
#
#
#
# #gradient descent based algo
# linear regression
# logistic regression
# neural network
#
#
# #tree based alg
# decisiontree
# random forest
# xgboost

# %% [markdown]
# # types of feature scaling
# min max scaler
# standard scaler
# max abs scaler
# robust scaler
# quantile transformer scaler
# power transformer scaler
# unit vector scaler
